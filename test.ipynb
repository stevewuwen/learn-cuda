# %% [markdown]
# <a href="https://colab.research.google.com/github/stevewuwen/learn-cuda/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile test.cu
# #include <iostream>
# #include <cmath>      // For fabs
# #include <algorithm>  // For std::max
# using namespace std;
#
# __global__ void add(int *a, int *b, int *c, int N){
#     int index = blockDim.x*blockIdx.x + threadIdx.x;
#
#     if(index < N){
#         c[index] = a[index] + b[index];
#     }
# }
#
# int main(){
#     int *a;
#     int *b;
#     int *c;
#     int N = 200;
#     cudaMallocManaged(&a, N*sizeof(int));
#     cudaMallocManaged(&b, N*sizeof(int));
#     cudaMallocManaged(&c, N*sizeof(int));
#     for (int i = 0; i < N; i++)
#     {
#         a[i] = 1;
#         b[i] = 1;
#         c[i] = 0;
#     }
#
#     int blockSize = 256;
#     int blockNum = (N+blockSize-1)/blockSize;
#     add<<<blockNum , blockSize>>>(a,b,c,N);
#     cudaDeviceSynchronize();
#     float maxError = 0;
#     for(int i=0;i<N;i+=1){
#         if(fabs(c[i]-2)>maxError){
#             std::cout<<fabs(c[i]-2)<<std::endl;
#         }
#         maxError = max(fabs(c[i]-2), maxError);
#     }
#     std::cout<<"max error: "<<maxError<<std::endl;
# }
# Out:
# Writing test.cu

# %%
# !docker ps
# Out:
# /bin/bash: line 1: docker: command not found

# %%
import random
random.shuffle()
# Out:
# test  test.cu
# max error: 0
